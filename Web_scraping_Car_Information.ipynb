# %%
import requests, bs4, re
from urllib.parse import urljoin
from bs4 import BeautifulSoup
from urllib.request import urlretrieve
import pandas as pd
import lxml.html

# Specify url FORD ESCORT  Safety
url = 'https://www.autoblog.com/buy/2017-Ford-Escape/safety-features/'


# create a BeautifulSoup object from the HTML: soup
def make_soup(url):
    r = requests.get(url)
    soup = bs4.BeautifulSoup(r.text, 'lxml')
    return soup
    
    

#create a BeautifulSoup object from the HTML: soup
soup = make_soup(url)


#find all saftey features for Ford_Escape_Saftey_2017
Ford_Escape_Saftey_2017 = soup.find_all('div', {'class': 'overview-item'})
Ford_Escape_Saftey_2017 = soup.find_all('h3')

for i in Ford_Escape_Saftey_2017:
    print(i.text)
# Out:
# Anti-lock brakes
# Stability control
# Front-impact airbags
# Side impact airbags
# Overhead airbags
# Knee airbags
# Pretensioners
# Security system
# NHTSA Frontal Crash Test Ratings
# IIHS Frontal Offset Crash Test Ratings
# SUMMARY
# CONSEQUENCES
# REMEDY
# COMPONENT AFFECTED
# NOTES
# (S) 4dr Front-wheel Drive
# (SE) 4dr Front-wheel Drive
# (SE) 4dr 4x4
# (Titanium) 4dr Front-wheel Drive
# (Titanium) 4dr 4x4
# Login
# Research another vehicle

# %%
# Specify url FORD Maintenence cost
url = 'https://repairpal.com/cars/ford/escape/2017'


# create a BeautifulSoup object from the HTML: soup
def make_soup(url):
    r = requests.get(url)
    soup = bs4.BeautifulSoup(r.text, 'lxml')
    return soup
    
    

#create a BeautifulSoup object from the HTML: soup
soup = make_soup(url)

# %%
#find all saftey features for Ford_Escape_Maintenance
Ford_Escape_Maintenance = soup.find_all('div', {'class': 'flex'})
Ford_Escape_Maintenance = soup.find_all('div', {'class': 'prh h2'})

for i in Ford_Escape_Maintenance:
    print(i.text)
# Out:
# $569

# %%
# Specify url price point Ford Escort
url = 'https://www.kbb.com/cars-for-sale/cars/used-cars/ford/escape/?vehicleid=415975&year=2017&distance=75'


# create a BeautifulSoup object from the HTML: soup
def make_soup(url):
    r = requests.get(url)
    soup = bs4.BeautifulSoup(r.text, 'lxml')
    return soup
    
    

#create a BeautifulSoup object from the HTML: soup
soup = make_soup(url)

#find all saftey features for Ford_Escape_Maintenance
Ford_Escape_Price = soup.find_all('div', {'class':"listing js-used-listing"})

Ford_Escape_Price = soup.find_all('span', {'class': 'title-four highlight'})

for i in Ford_Escape_Price:
    print(i.text)
# Out:
# 					$13,990
#
#
# 					$14,993
#
#
# 					$19,000
#
#
# 					$15,490
#
#
# 					$15,695
#
#
# 					$15,900
#
#
# 					$15,998
#
#
# 					$15,994
#
#
# 					$15,998
#
#
# 					$15,999
#
#
# 					$16,057
#
#
# 					$16,104
#
#
# 					$16,200
#
#
# 					$16,207
#
#
# 					$18,730
#
#
# 					$16,459
#
#
# 					$16,469
#
#
# 					$16,500
#
#
# 					$16,500
#
#
# 					$16,500
#
#
# 					$16,795
#
#
# 					$16,799
#
#
# 					$16,900
#
#
# 					$16,981
#
#
# 					$16,994
#
#
# 					$17,000
#
#
# 					$17,000
#
#
# 					$17,000

# %%
import numpy as np

Safety_list = {}
Safety_list['Safety Features'] = []
features = Safety_list['Safety Features']

Maint_list = {}
Maint_list['Maintenence Cost'] = []
maint_cost = Maint_list['Maintenence Cost']

Price_list = {}
Price_list['Pricing'] = []
price = Price_list['Pricing']

for i in Ford_Escape_Saftey_2017:
    new_feature = "{" + "Ford Escort 2017" + ":" + i.text + "}"
    features.append(new_feature)
    new_feature = {}
    

for i in Ford_Escape_Maintenance:
    new_cost = "{" + "Ford Escort 2017" + ":" + i.text + "}"
    maint_cost.append(new_cost)
    new_cost = {}
    
for i in Ford_Escape_Price:
    new_price = "{" + "Ford Escort 2017" + ":" + i.text.strip() + "}"
    price.append(new_price)
    new_price = {}
# Out:
# {'Safety Features': ['{Ford Escort 2017:Anti-lock brakes}',
#   '{Ford Escort 2017:Stability control}',
#   '{Ford Escort 2017:Front-impact airbags}',
#   '{Ford Escort 2017:Side impact airbags}',
#   '{Ford Escort 2017:Overhead airbags}',
#   '{Ford Escort 2017:Knee airbags}',
#   '{Ford Escort 2017:Pretensioners}',
#   '{Ford Escort 2017:Security system}',
#   '{Ford Escort 2017:NHTSA Frontal Crash Test Ratings}',
#   '{Ford Escort 2017:IIHS Frontal Offset Crash Test Ratings}',
#   '{Ford Escort 2017:SUMMARY}',
#   '{Ford Escort 2017:CONSEQUENCES}',
#   '{Ford Escort 2017:REMEDY}',
#   '{Ford Escort 2017:COMPONENT AFFECTED}',
#   '{Ford Escort 2017:NOTES}',
#   '{Ford Escort 2017:(S) 4dr Front-wheel Drive}',
#   '{Ford Escort 2017:(SE) 4dr Front-wheel Drive}',
#   '{Ford Escort 2017:(SE) 4dr 4x4}',
#   '{Ford Escort 2017:(Titanium) 4dr Front-wheel Drive}',
#   '{Ford Escort 2017:(Titanium) 4dr 4x4}',
#   '{Ford Escort 2017:Login}',
# ...

# %%
# Specify url HONDA Safety
url = 'https://www.autoblog.com/buy/2017-Honda-CR_V/safety-features/'


# create a BeautifulSoup object from the HTML: soup
def make_soup(url):
    r = requests.get(url)
    soup = bs4.BeautifulSoup(r.text, 'lxml')
    return soup
    
    

#create a BeautifulSoup object from the HTML: soup
soup = make_soup(url)


#find all saftey features for Ford_Escape_Saftey_2017
Honda_CRV_Saftey_2017 = soup.find_all('div', {'class': 'overview-item'})
Honda_CRV_Saftey_2017 = soup.find_all('h3')

for i in Honda_CRV_Saftey_2017:
    print(i.text)
# Out:
# Anti-lock brakes
# Stability control
# Front-impact airbags
# Side impact airbags
# Overhead airbags
# Pretensioners
# Security system
# NHTSA Frontal Crash Test Ratings
# IIHS Frontal Offset Crash Test Ratings
# SUMMARY
# CONSEQUENCES
# REMEDY
# COMPONENT AFFECTED
# NOTES
# (LX) 4dr Front-wheel Drive
# (LX) 4dr All-wheel Drive
# (EX) 4dr Front-wheel Drive
# (EX) 4dr All-wheel Drive
# (EX-L) 4dr Front-wheel Drive
# (EX-L) 4dr All-wheel Drive
# (Touring) 4dr Front-wheel Drive
# (Touring) 4dr All-wheel Drive
# Login
# Research another vehicle

# %%
for i in Honda_CRV_Saftey_2017:
    new_feature = "{" + "HONDA CRV 2017" + ":" + i.text + "}"
    features.append(new_feature)
    new_feature = {}
    
Safety_list
# Out:
# {'Safety Features': ['{Ford Escort 2017:Anti-lock brakes}',
#   '{Ford Escort 2017:Stability control}',
#   '{Ford Escort 2017:Front-impact airbags}',
#   '{Ford Escort 2017:Side impact airbags}',
#   '{Ford Escort 2017:Overhead airbags}',
#   '{Ford Escort 2017:Knee airbags}',
#   '{Ford Escort 2017:Pretensioners}',
#   '{Ford Escort 2017:Security system}',
#   '{Ford Escort 2017:NHTSA Frontal Crash Test Ratings}',
#   '{Ford Escort 2017:IIHS Frontal Offset Crash Test Ratings}',
#   '{Ford Escort 2017:SUMMARY}',
#   '{Ford Escort 2017:CONSEQUENCES}',
#   '{Ford Escort 2017:REMEDY}',
#   '{Ford Escort 2017:COMPONENT AFFECTED}',
#   '{Ford Escort 2017:NOTES}',
#   '{Ford Escort 2017:(S) 4dr Front-wheel Drive}',
#   '{Ford Escort 2017:(SE) 4dr Front-wheel Drive}',
#   '{Ford Escort 2017:(SE) 4dr 4x4}',
#   '{Ford Escort 2017:(Titanium) 4dr Front-wheel Drive}',
#   '{Ford Escort 2017:(Titanium) 4dr 4x4}',
#   '{Ford Escort 2017:Login}',
# ...

# %%
# Specify url Hyundai Safety
url = 'https://www.autoblog.com/buy/2017-Hyundai-Santa+Fe/safety-features/'


# create a BeautifulSoup object from the HTML: soup
def make_soup(url):
    r = requests.get(url)
    soup = bs4.BeautifulSoup(r.text, 'lxml')
    return soup
    
    

#create a BeautifulSoup object from the HTML: soup
soup = make_soup(url)


#find all saftey features for Ford_Escape_Saftey_2017
Hyundai_Saftey_2017 = soup.find_all('div', {'class': 'overview-item'})
Hyundai_Saftey_2017 = soup.find_all('h3')

for i in Hyundai_Saftey_2017:
    print(i.text)
# Out:
# Anti-lock brakes
# Stability control
# Front-impact airbags
# Side impact airbags
# Overhead airbags
# Knee airbags
# Pretensioners
# Security system
# IIHS Frontal Offset Crash Test Ratings
# SUMMARY
# CONSEQUENCES
# REMEDY
# COMPONENT AFFECTED
# NOTES
# (SE) 4dr Front-wheel Drive
# (SE) 4dr All-wheel Drive
# (Limited) 4dr Front-wheel Drive
# (Limited) 4dr All-wheel Drive
# (SE Ultimate) 4dr Front-wheel Drive
# (Limited Ultimate) 4dr Front-wheel Drive
# (SE Ultimate) 4dr All-wheel Drive
# (Limited Ultimate) 4dr All-wheel Drive
# Login
# Research another vehicle

# %%
for i in Hyundai_Saftey_2017:
    new_feature = "{" + "Hyundai Santa Fe 2017" + ":" + i.text + "}"
    features.append(new_feature)
    new_feature = {}
    
Safety_list
# Out:
# {'Safety Features': ['{Ford Escort 2017:Anti-lock brakes}',
#   '{Ford Escort 2017:Stability control}',
#   '{Ford Escort 2017:Front-impact airbags}',
#   '{Ford Escort 2017:Side impact airbags}',
#   '{Ford Escort 2017:Overhead airbags}',
#   '{Ford Escort 2017:Knee airbags}',
#   '{Ford Escort 2017:Pretensioners}',
#   '{Ford Escort 2017:Security system}',
#   '{Ford Escort 2017:NHTSA Frontal Crash Test Ratings}',
#   '{Ford Escort 2017:IIHS Frontal Offset Crash Test Ratings}',
#   '{Ford Escort 2017:SUMMARY}',
#   '{Ford Escort 2017:CONSEQUENCES}',
#   '{Ford Escort 2017:REMEDY}',
#   '{Ford Escort 2017:COMPONENT AFFECTED}',
#   '{Ford Escort 2017:NOTES}',
#   '{Ford Escort 2017:(S) 4dr Front-wheel Drive}',
#   '{Ford Escort 2017:(SE) 4dr Front-wheel Drive}',
#   '{Ford Escort 2017:(SE) 4dr 4x4}',
#   '{Ford Escort 2017:(Titanium) 4dr Front-wheel Drive}',
#   '{Ford Escort 2017:(Titanium) 4dr 4x4}',
#   '{Ford Escort 2017:Login}',
# ...

# %%
# Specify url Toyota Rav 4 Safety
url = 'https://www.autoblog.com/buy/2017-Toyota-RAV4/safety-features/'


# create a BeautifulSoup object from the HTML: soup
def make_soup(url):
    r = requests.get(url)
    soup = bs4.BeautifulSoup(r.text, 'lxml')
    return soup
    
    

#create a BeautifulSoup object from the HTML: soup
soup = make_soup(url)


#find all saftey features for Ford_Escape_Saftey_2017
Toyota_Saftey_2017 = soup.find_all('div', {'class': 'overview-item'})
Toyota_Saftey_2017 = soup.find_all('h3')

for i in Toyota_Saftey_2017:
    print(i.text)
# Out:
# Anti-lock brakes
# Stability control
# Front-impact airbags
# Side impact airbags
# Overhead airbags
# Knee airbags
# Pretensioners
# Security system
# NHTSA Frontal Crash Test Ratings
# IIHS Frontal Offset Crash Test Ratings
# SUMMARY
# CONSEQUENCES
# REMEDY
# COMPONENT AFFECTED
# NOTES
# (LE) 4dr Front-wheel Drive
# (XLE) 4dr Front-wheel Drive
# (LE) 4dr All-wheel Drive
# (XLE) 4dr All-wheel Drive
# (SE) 4dr Front-wheel Drive
# (SE) 4dr All-wheel Drive
# (Limited) 4dr Front-wheel Drive
# (Limited) 4dr All-wheel Drive
# (Platinum) 4dr Front-wheel Drive
# (Platinum) 4dr All-wheel Drive
# Login
# Research another vehicle

# %%
for i in Toyota_Saftey_2017:
    new_feature = "{" + "Toyota Rav 4 2017" + ":" + i.text + "}"
    features.append(new_feature)
    new_feature = {}
    
Safety_list
# Out:
# {'Safety Features': ['{Ford Escort 2017:Anti-lock brakes}',
#   '{Ford Escort 2017:Stability control}',
#   '{Ford Escort 2017:Front-impact airbags}',
#   '{Ford Escort 2017:Side impact airbags}',
#   '{Ford Escort 2017:Overhead airbags}',
#   '{Ford Escort 2017:Knee airbags}',
#   '{Ford Escort 2017:Pretensioners}',
#   '{Ford Escort 2017:Security system}',
#   '{Ford Escort 2017:NHTSA Frontal Crash Test Ratings}',
#   '{Ford Escort 2017:IIHS Frontal Offset Crash Test Ratings}',
#   '{Ford Escort 2017:SUMMARY}',
#   '{Ford Escort 2017:CONSEQUENCES}',
#   '{Ford Escort 2017:REMEDY}',
#   '{Ford Escort 2017:COMPONENT AFFECTED}',
#   '{Ford Escort 2017:NOTES}',
#   '{Ford Escort 2017:(S) 4dr Front-wheel Drive}',
#   '{Ford Escort 2017:(SE) 4dr Front-wheel Drive}',
#   '{Ford Escort 2017:(SE) 4dr 4x4}',
#   '{Ford Escort 2017:(Titanium) 4dr Front-wheel Drive}',
#   '{Ford Escort 2017:(Titanium) 4dr 4x4}',
#   '{Ford Escort 2017:Login}',
# ...

# %%
# Specify url 2017 Honda CRV  Maintenence cost
url = 'https://repairpal.com/honda/cr-v'


# create a BeautifulSoup object from the HTML: soup
def make_soup(url):
    r = requests.get(url)
    soup = bs4.BeautifulSoup(r.text, 'lxml')
    return soup
    
    

#create a BeautifulSoup object from the HTML: soup
soup = make_soup(url)

# %%
#find all Honda  Maintenance
Honda_Maintenance = soup.find_all('div', {'class': 'flex'})
Honda_Maintenance = soup.find_all('div', {'class': 'prh h2'})

for i in Honda_Maintenance:
    print(i.text)
# Out:
# $403

# %%
for i in Honda_Maintenance:
    new_cost = "{" + "Honda CRV 2017" + ":" + i.text + "}"
    maint_cost.append(new_cost)
    new_cost = {}
    
Maint_list
# Out:
# {'Maintenence Cost': ['{Ford Escort 2017:$569 }', '{Honda CRV 2017:$403 }']}

# %%
# Specify url 2017 Hyundai  Maintenence cost
url = 'https://repairpal.com/hyundai/santa+fe'


# create a BeautifulSoup object from the HTML: soup
def make_soup(url):
    r = requests.get(url)
    soup = bs4.BeautifulSoup(r.text, 'lxml')
    return soup
    
    

#create a BeautifulSoup object from the HTML: soup
soup = make_soup(url)

# %%
#find all Hyundai  Maintenance
Hyundai_Maintenance = soup.find_all('div', {'class': 'flex'})
Hyundai_Maintenance = soup.find_all('div', {'class': 'prh h2'})

for i in Hyundai_Maintenance:
    print(i.text)
# Out:
# $464

# %%
for i in Hyundai_Maintenance:
    new_cost = "{" + "Hyundai Sante Fe 2017" + ":" + i.text + "}"
    maint_cost.append(new_cost)
    new_cost = {}
    
Maint_list
# Out:
# {'Maintenence Cost': ['{Ford Escort 2017:$569 }',
#   '{Honda CRV 2017:$403 }',
#   '{Hyundai Sante Fe 2017:$464 }']}

# %%
# Specify url 2017 Hyundai  Maintenence cost
url = 'https://repairpal.com/toyota/rav4'


# create a BeautifulSoup object from the HTML: soup
def make_soup(url):
    r = requests.get(url)
    soup = bs4.BeautifulSoup(r.text, 'lxml')
    return soup
    
    

#create a BeautifulSoup object from the HTML: soup
soup = make_soup(url)

#find all Hyundai  Maintenance
Toyota_Maintenance = soup.find_all('div', {'class': 'flex'})
Toyota_Maintenance = soup.find_all('div', {'class': 'prh h2'})

for i in Toyota_Maintenance:
    print(i.text)
# Out:
# $428

# %%
for i in Toyota_Maintenance:
    new_cost = "{" + "Toyota Rav4 2017" + ":" + i.text + "}"
    maint_cost.append(new_cost)
    new_cost = {}
    
Maint_list
# Out:
# {'Maintenence Cost': ['{Ford Escort 2017:$569 }',
#   '{Honda CRV 2017:$403 }',
#   '{Hyundai Sante Fe 2017:$464 }',
#   '{Toyota Rav4 2017:$428 }']}

# %%
# Specify url price point Honda CRV
url = 'https://www.kbb.com/cars-for-sale/cars/used-cars/honda/cr-v/?vehicleid=422663&year=2017&distance=75'


# create a BeautifulSoup object from the HTML: soup
def make_soup(url):
    r = requests.get(url)
    soup = bs4.BeautifulSoup(r.text, 'lxml')
    return soup
    
    

#create a BeautifulSoup object from the HTML: soup
soup = make_soup(url)

#find all saftey features for Ford_Escape_Maintenance
Honda_Price = soup.find_all('div', {'class':"listing js-used-listing"})

Honda_Price = soup.find_all('span', {'class': 'title-four highlight'})

for i in Honda_Price:
    print(i.text)
# Out:
# 					$19,400
#
#
# 					$20,788
#
#
# 					$21,644
#
#
# 					$20,791
#
#
# 					$20,992
#
#
# 					$21,294
#
#
# 					$27,200
#
#
# 					$21,395
#
#
# 					$21,692
#
#
# 					$21,895
#
#
# 					$21,899
#
#
# 					$21,902
#
#
# 					$21,995
#
#
# 					$22,000
#
#
# 					$18,348
#
#
# 					$22,000
#
#
# 					$22,295
#
#
# 					$22,390
#
#
# 					$22,400
#
#
# 					$22,481
#
#
# 					$22,495
#
#
# 					$22,497
#
#
# 					$22,499
#
#
# 					$22,500
#
#
# 					$22,700
#
#
# 					$22,924
#
#
# 					$22,991
#
#
# 					$22,995

# %%
for i in Honda_Price:
    new_price = "{" + "Honda CRV 2017" + ":" + i.text.strip() + "}"
    price.append(new_price)
    new_price = {}
    
Price_list
# Out:
# {'Pricing': ['{Ford Escort 2017:$13,990}',
#   '{Ford Escort 2017:$14,993}',
#   '{Ford Escort 2017:$19,000}',
#   '{Ford Escort 2017:$15,490}',
#   '{Ford Escort 2017:$15,695}',
#   '{Ford Escort 2017:$15,900}',
#   '{Ford Escort 2017:$15,998}',
#   '{Ford Escort 2017:$15,994}',
#   '{Ford Escort 2017:$15,998}',
#   '{Ford Escort 2017:$15,999}',
#   '{Ford Escort 2017:$16,057}',
#   '{Ford Escort 2017:$16,104}',
#   '{Ford Escort 2017:$16,200}',
#   '{Ford Escort 2017:$16,207}',
#   '{Ford Escort 2017:$18,730}',
#   '{Ford Escort 2017:$16,459}',
#   '{Ford Escort 2017:$16,469}',
#   '{Ford Escort 2017:$16,500}',
#   '{Ford Escort 2017:$16,500}',
#   '{Ford Escort 2017:$16,500}',
#   '{Ford Escort 2017:$16,795}',
#   '{Ford Escort 2017:$16,799}',
#   '{Ford Escort 2017:$16,900}',
#   '{Ford Escort 2017:$16,981}',
#   '{Ford Escort 2017:$16,994}',
#   '{Ford Escort 2017:$17,000}',
#   '{Ford Escort 2017:$17,000}',
#   '{Ford Escort 2017:$17,000}',
#   '{Honda CRV 2017:$19,400}',
# ...

# %%
# Specify url price point Hyundai CRV
url = 'https://www.kbb.com/cars-for-sale/cars/used-cars/hyundai/santa-fe/?vehicleid=415732&year=2017&distance=75'


# create a BeautifulSoup object from the HTML: soup
def make_soup(url):
    r = requests.get(url)
    soup = bs4.BeautifulSoup(r.text, 'lxml')
    return soup
    
    

#create a BeautifulSoup object from the HTML: soup
soup = make_soup(url)

#find all saftey features for Ford_Escape_Maintenance
Hyundai_Price = soup.find_all('div', {'class':"listing js-used-listing"})

Hyundai_Price = soup.find_all('span', {'class': 'title-four highlight'})

for i in Hyundai_Price:
    print(i.text)
# Out:
# 					$16,498
#
#
# 					$16,900
#
#
# 					$19,300
#
#
# 					$16,990
#
#
# 					$17,000
#
#
# 					$17,200
#
#
# 					$16,500
#
#
# 					$17,635
#
#
# 					$17,998
#
#
# 					$18,115
#
#
# 					$18,295
#
#
# 					$18,500
#
#
# 					$18,600
#
#
# 					$18,625
#
#
# 					$16,000
#
#
# 					$18,777
#
#
# 					$18,790
#
#
# 					$18,795
#
#
# 					$18,859
#
#
# 					$18,895
#
#
# 					$18,914
#
#
# 					$18,977
#
#
# 					$18,990
#
#
# 					$18,995
#
#
# 					$18,998
#
#
# 					$19,114
#
#
# 					$19,399
#
#
# 					$19,500

# %%
for i in Hyundai_Price:
    new_price = "{" + "Hyundai CRV 2017" + ":" + i.text.strip() + "}"
    price.append(new_price)
    new_price = {}
    
Price_list
# Out:
# {'Pricing': ['{Ford Escort 2017:$13,990}',
#   '{Ford Escort 2017:$14,993}',
#   '{Ford Escort 2017:$19,000}',
#   '{Ford Escort 2017:$15,490}',
#   '{Ford Escort 2017:$15,695}',
#   '{Ford Escort 2017:$15,900}',
#   '{Ford Escort 2017:$15,998}',
#   '{Ford Escort 2017:$15,994}',
#   '{Ford Escort 2017:$15,998}',
#   '{Ford Escort 2017:$15,999}',
#   '{Ford Escort 2017:$16,057}',
#   '{Ford Escort 2017:$16,104}',
#   '{Ford Escort 2017:$16,200}',
#   '{Ford Escort 2017:$16,207}',
#   '{Ford Escort 2017:$18,730}',
#   '{Ford Escort 2017:$16,459}',
#   '{Ford Escort 2017:$16,469}',
#   '{Ford Escort 2017:$16,500}',
#   '{Ford Escort 2017:$16,500}',
#   '{Ford Escort 2017:$16,500}',
#   '{Ford Escort 2017:$16,795}',
#   '{Ford Escort 2017:$16,799}',
#   '{Ford Escort 2017:$16,900}',
#   '{Ford Escort 2017:$16,981}',
#   '{Ford Escort 2017:$16,994}',
#   '{Ford Escort 2017:$17,000}',
#   '{Ford Escort 2017:$17,000}',
#   '{Ford Escort 2017:$17,000}',
#   '{Honda CRV 2017:$19,400}',
# ...

# %%
# Specify url price point Toyota Rav4
url = 'https://www.kbb.com/cars-for-sale/cars/used-cars/toyota/rav4/?vehicleid=421396&year=2017&distance=75'


# create a BeautifulSoup object from the HTML: soup
def make_soup(url):
    r = requests.get(url)
    soup = bs4.BeautifulSoup(r.text, 'lxml')
    return soup
    
    

#create a BeautifulSoup object from the HTML: soup
soup = make_soup(url)

#find all saftey features for Ford_Escape_Maintenance
Toyota_Price = soup.find_all('div', {'class':"listing js-used-listing"})

Toyota_Price = soup.find_all('span', {'class': 'title-four highlight'})

for i in Toyota_Price:
    print(i.text)
# Out:
# 					$17,492
#
#
# 					$17,529
#
#
# 					$19,230
#
#
# 					$17,829
#
#
# 					$17,866
#
#
# 					$17,989
#
#
# 					$28,934
#
#
# 					$17,995
#
#
# 					$17,999
#
#
# 					$17,999
#
#
# 					$18,300
#
#
# 					$18,400
#
#
# 					$18,795
#
#
# 					$18,800
#
#
# 					$23,991
#
#
# 					$18,981
#
#
# 					$18,988
#
#
# 					$19,000
#
#
# 					$19,230
#
#
# 					$19,279
#
#
# 					$19,300
#
#
# 					$19,500
#
#
# 					$19,513
#
#
# 					$19,794
#
#
# 					$19,830
#
#
# 					$19,900
#
#
# 					$19,995
#
#
# 					$19,998

# %%
for i in Toyota_Price:
    new_price = "{" + "Toyota Rav4 2017" + ":" + i.text.strip() + "}"
    price.append(new_price)
    new_price = {}
    
Price_list
# Out:
# {'Pricing': ['{Ford Escort 2017:$13,990}',
#   '{Ford Escort 2017:$14,993}',
#   '{Ford Escort 2017:$19,000}',
#   '{Ford Escort 2017:$15,490}',
#   '{Ford Escort 2017:$15,695}',
#   '{Ford Escort 2017:$15,900}',
#   '{Ford Escort 2017:$15,998}',
#   '{Ford Escort 2017:$15,994}',
#   '{Ford Escort 2017:$15,998}',
#   '{Ford Escort 2017:$15,999}',
#   '{Ford Escort 2017:$16,057}',
#   '{Ford Escort 2017:$16,104}',
#   '{Ford Escort 2017:$16,200}',
#   '{Ford Escort 2017:$16,207}',
#   '{Ford Escort 2017:$18,730}',
#   '{Ford Escort 2017:$16,459}',
#   '{Ford Escort 2017:$16,469}',
#   '{Ford Escort 2017:$16,500}',
#   '{Ford Escort 2017:$16,500}',
#   '{Ford Escort 2017:$16,500}',
#   '{Ford Escort 2017:$16,795}',
#   '{Ford Escort 2017:$16,799}',
#   '{Ford Escort 2017:$16,900}',
#   '{Ford Escort 2017:$16,981}',
#   '{Ford Escort 2017:$16,994}',
#   '{Ford Escort 2017:$17,000}',
#   '{Ford Escort 2017:$17,000}',
#   '{Ford Escort 2017:$17,000}',
#   '{Honda CRV 2017:$19,400}',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-138-56f00bae0af2> in <module>
#       6
#       7 #open csv file to write to Features
# ----> 8 w = csv.writer(csv)
#       9
#      10 for key, val in Maint_list.items():
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'writer'

# %%
len(features)
# Out:
# 97

# %%
print(csv.close())
# Out:
# None
